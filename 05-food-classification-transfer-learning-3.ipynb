# %%
import os
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from helper_function import create_tensorboard_callback, plot_loss_curves, unzip_data, walk_through_dir
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ### 1. Data preparation

# %%
train_dir_path = "image_data/101_food_classes_10_percent/train/"
test_dir_path = "image_data/101_food_classes_10_percent/test/"

# %%
### Walk thro image data path

walk_through_dir("image_data/101_food_classes_10_percent")
# Out:
# There are 2 directories and 0 images in 'image_data/101_food_classes_10_percent'.
# There are 101 directories and 0 images in 'image_data/101_food_classes_10_percent\test'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\apple_pie'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\baby_back_ribs'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\baklava'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\beef_carpaccio'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\beef_tartare'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\beet_salad'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\beignets'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\bibimbap'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\bread_pudding'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\breakfast_burrito'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\bruschetta'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\caesar_salad'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\cannoli'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\caprese_salad'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\carrot_cake'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\ceviche'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\cheesecake'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\cheese_plate'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\chicken_curry'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\chicken_quesadilla'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\chicken_wings'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\chocolate_cake'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\chocolate_mousse'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\churros'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\clam_chowder'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\club_sandwich'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\crab_cakes'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\creme_brulee'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\croque_madame'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\cup_cakes'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\deviled_eggs'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\donuts'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\dumplings'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\edamame'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\eggs_benedict'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\escargots'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\falafel'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\filet_mignon'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\fish_and_chips'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\foie_gras'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\french_fries'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\french_onion_soup'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\french_toast'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\fried_calamari'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\fried_rice'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\frozen_yogurt'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\garlic_bread'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\gnocchi'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\greek_salad'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\grilled_cheese_sandwich'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\grilled_salmon'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\guacamole'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\gyoza'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\hamburger'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\hot_and_sour_soup'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\hot_dog'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\huevos_rancheros'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\hummus'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\ice_cream'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\lasagna'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\lobster_bisque'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\lobster_roll_sandwich'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\macaroni_and_cheese'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\macarons'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\miso_soup'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\mussels'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\nachos'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\omelette'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\onion_rings'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\oysters'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\pad_thai'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\paella'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\pancakes'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\panna_cotta'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\peking_duck'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\pho'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\pizza'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\pork_chop'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\poutine'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\prime_rib'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\pulled_pork_sandwich'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\ramen'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\ravioli'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\red_velvet_cake'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\risotto'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\samosa'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\sashimi'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\scallops'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\seaweed_salad'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\shrimp_and_grits'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\spaghetti_bolognese'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\spaghetti_carbonara'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\spring_rolls'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\steak'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\strawberry_shortcake'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\sushi'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\tacos'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\takoyaki'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\tiramisu'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\tuna_tartare'.
# There are 0 directories and 250 images in 'image_data/101_food_classes_10_percent\test\waffles'.
# There are 101 directories and 0 images in 'image_data/101_food_classes_10_percent\train'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\apple_pie'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\baby_back_ribs'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\baklava'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\beef_carpaccio'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\beef_tartare'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\beet_salad'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\beignets'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\bibimbap'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\bread_pudding'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\breakfast_burrito'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\bruschetta'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\caesar_salad'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\cannoli'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\caprese_salad'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\carrot_cake'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\ceviche'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\cheesecake'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\cheese_plate'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\chicken_curry'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\chicken_quesadilla'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\chicken_wings'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\chocolate_cake'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\chocolate_mousse'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\churros'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\clam_chowder'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\club_sandwich'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\crab_cakes'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\creme_brulee'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\croque_madame'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\cup_cakes'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\deviled_eggs'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\donuts'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\dumplings'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\edamame'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\eggs_benedict'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\escargots'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\falafel'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\filet_mignon'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\fish_and_chips'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\foie_gras'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\french_fries'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\french_onion_soup'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\french_toast'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\fried_calamari'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\fried_rice'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\frozen_yogurt'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\garlic_bread'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\gnocchi'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\greek_salad'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\grilled_cheese_sandwich'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\grilled_salmon'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\guacamole'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\gyoza'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\hamburger'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\hot_and_sour_soup'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\hot_dog'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\huevos_rancheros'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\hummus'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\ice_cream'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\lasagna'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\lobster_bisque'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\lobster_roll_sandwich'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\macaroni_and_cheese'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\macarons'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\miso_soup'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\mussels'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\nachos'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\omelette'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\onion_rings'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\oysters'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\pad_thai'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\paella'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\pancakes'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\panna_cotta'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\peking_duck'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\pho'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\pizza'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\pork_chop'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\poutine'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\prime_rib'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\pulled_pork_sandwich'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\ramen'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\ravioli'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\red_velvet_cake'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\risotto'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\samosa'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\sashimi'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\scallops'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\seaweed_salad'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\shrimp_and_grits'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\spaghetti_bolognese'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\spaghetti_carbonara'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\spring_rolls'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\steak'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\strawberry_shortcake'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\sushi'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\tacos'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\takoyaki'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\tiramisu'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\tuna_tartare'.
# There are 0 directories and 75 images in 'image_data/101_food_classes_10_percent\train\waffles'.

# %%
img_size = (224, 224)

### Shuffle for training data to prevent overfitting
train_data_10_percent = tf.keras.preprocessing.image_dataset_from_directory(directory = train_dir_path,
    image_size = img_size, label_mode = "categorical", batch_size = 32)

### Don't shuffle testing data, we do not need it on testing
test_data = tf.keras.preprocessing.image_dataset_from_directory(directory = test_dir_path,
    image_size = img_size, label_mode = "categorical")
# Out:
# Found 7575 files belonging to 101 classes.
# Found 25250 files belonging to 101 classes.

# %%
### Create check point

### Save only the model weight
### Save the model`s weight which score the best validation accuracy
checkpoint_path = "101_classes_10_percent_transfer_learning_3_checkpoint"
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, save_weights_only = True,
    monitor = "val_accuracy", save_best_only = True)

# %%
### Create data augmentation

data_augmentation = Sequential([
  layers.RandomFlip("horizontal"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(0.2),
  layers.RandomHeight(0.2),
  layers.RandomWidth(0.2),
], name = "data_augmentation")

# %%
base_model = tf.keras.applications.efficientnet.EfficientNetB0(include_top = False)
base_model.trainable = False

input_layer = layers.Input(shape = (224, 224, 3), name = "input_layer")

x = data_augmentation(input_layer)
x = base_model(x, training = False)
x = layers.GlobalAveragePooling2D(name = "global_average_pooling")(x)

output_layer = layers.Dense(len(train_data_10_percent.class_names), activation = "softmax", name = "output_layer")(x)

model = tf.keras.Model(input_layer, output_layer)

model.compile(loss = "categorical_crossentropy", optimizer = tf.keras.optimizers.Adam(),
    metrics = ["accuracy"])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  data_augmentation (Sequent  (None, None, None, 3)     0
#  ial)
#
#  efficientnetb0 (Functional  (None, None, None, 1280   4049571
#  )                           )
#
#  global_average_pooling (Gl  (None, 1280)              0
#  obalAveragePooling2D)
#
#  output_layer (Dense)        (None, 101)               129381
#
# =================================================================
# Total params: 4178952 (15.94 MB)
# Trainable params: 129381 (505.39 KB)
# Non-trainable params: 4049571 (15.45 MB)
# _________________________________________________________________
